# %%
import os

folder_path = "Dataset\\labels\\train"


os.listdir(folder_path)
# Out:
# ['10.txt',
#  '100.txt',
#  '101.txt',
#  '102.txt',
#  '103.txt',
#  '104.txt',
#  '105.txt',
#  '106.txt',
#  '107.txt',
#  '108.txt',
#  '109.txt',
#  '110.txt',
#  '115.txt',
#  '116.txt',
#  '117.txt',
#  '118.txt',
#  '119.txt',
#  '123.txt',
#  '124.txt',
#  '125.txt',
#  '126.txt',
#  '129.txt',
#  '13.txt',
#  '130.txt',
#  '131.txt',
#  '132.txt',
#  '133.txt',
#  '134.txt',
#  '136.txt',
#  '137.txt',
#  '138.txt',
#  '14.txt',
#  '142.txt',
#  '143.txt',
#  '145.txt',
#  '146.txt',
#  '147.txt',
#  '149.txt',
#  '15.txt',
#  '150.txt',
#  '151.txt',
#  '153.txt',
#  '156.txt',
#  '157.txt',
#  '158.txt',
#  '159.txt',
#  '16.txt',
#  '160.txt',
#  '161.txt',
#  '163.txt',
#  '164.txt',
#  '166.txt',
#  '169.txt',
#  '17.txt',
#  '170.txt',
#  '172.txt',
#  '173.txt',
#  '174.txt',
#  '175.txt',
#  '176.txt',
#  '177.txt',
#  '178.txt',
#  '181.txt',
#  '182.txt',
#  '183.txt',
#  '184.txt',
#  '185.txt',
#  '186.txt',
#  '187.txt',
#  '188.txt',
#  '189.txt',
# ...

# %%
i = 0
list = []
for filename in os.listdir(folder_path):
    if filename.endswith(".txt"):
        file_path = os.path.join(folder_path, filename)
        with open(file_path, 'r') as file:
            for line in file:
                line = line.strip()
                if line.startswith('1'):
                    # print(f"The first character of line '{line}' in file '{filename}' is '1'")
                    i += 1
                    list.append(filename)

# %%
sorted(list)
# Out:
# ['115.jpg',
#  '166.jpg',
#  '166.jpg',
#  '181.jpg',
#  '181.jpg',
#  '182.jpg',
#  '183.jpg',
#  '185.jpg',
#  '186.jpg',
#  '186.jpg',
#  '187.jpg',
#  '188.jpg',
#  '189.jpg',
#  '200.jpg',
#  '211.jpg',
#  '211.jpg',
#  '212.jpg',
#  '213.jpg',
#  '221.jpg',
#  '222.jpg',
#  '222.jpg',
#  '223.jpg',
#  '224.jpg',
#  '227.jpg',
#  '228.jpg',
#  '236.jpg',
#  '244.jpg',
#  '248.jpg',
#  '248.jpg',
#  '249.jpg',
#  '250.jpg',
#  '251.jpg',
#  '252.jpg',
#  '256.jpg',
#  '267.jpg',
#  '268.jpg',
#  '268.jpg',
#  '275.jpg',
#  '282.jpg',
#  '285.jpg',
#  '285.jpg',
#  '291.jpg',
#  '294.jpg',
#  '300.jpg',
#  '309.jpg',
#  '311.jpg',
#  '312.jpg',
#  '313.jpg',
#  '333.jpg',
#  '336.jpg',
#  '343.jpg',
#  '353.jpg',
#  '362.jpg',
#  '363.jpg',
#  '369.jpg',
#  '370.jpg',
#  '379.jpg',
#  '379.jpg',
#  '380.jpg',
#  '383.jpg',
#  '384.jpg',
#  '387.jpg',
#  '388.jpg',
#  '389.jpg',
#  '390.jpg',
#  '390.jpg',
#  '398.jpg',
#  '405.jpg',
#  '428.jpg',
#  '446.jpg',
#  '447.jpg',
# ...

# %%
#rplace .txt with .jpg
list = [i.replace('.txt', '.jpg') for i in list]

# %%
#copy file from one folder to another
import os
import shutil

source_folder = "Dataset\\images\\train"
destination_folder = "destination_folder"

os.listdir(source_folder)
# Out:
# ['10.jpg',
#  '100.jpg',
#  '1001.jpeg',
#  '1002.jpeg',
#  '1003.jpeg',
#  '1004.jpeg',
#  '1005.jpeg',
#  '1006.jpeg',
#  '1007.jpeg',
#  '1008.jpeg',
#  '1009.jpeg',
#  '101.jpg',
#  '1010.jpeg',
#  '1011.jpeg',
#  '1012.jpeg',
#  '1013.jpeg',
#  '1014.jpeg',
#  '1015.jpeg',
#  '1016.jpeg',
#  '1017.jpeg',
#  '1018.jpeg',
#  '1019.jpeg',
#  '102.jpg',
#  '1020.jpeg',
#  '1021.jpeg',
#  '1022.jpeg',
#  '1023.jpeg',
#  '1024.jpeg',
#  '1025.jpeg',
#  '1026.jpeg',
#  '1027.jpeg',
#  '1028.jpeg',
#  '1029.jpeg',
#  '103.jpg',
#  '1030.jpeg',
#  '1031.jpeg',
#  '1032.jpeg',
#  '1033.jpeg',
#  '1034.jpeg',
#  '1035.jpeg',
#  '1036.jpeg',
#  '1037.jpeg',
#  '104.jpg',
#  '105.jpg',
#  '106.jpg',
#  '107.jpg',
#  '108.jpg',
#  '109.jpg',
#  '110.jpg',
#  '115.jpg',
#  '116.jpg',
#  '117.jpg',
#  '118.jpg',
#  '119.jpg',
#  '123.jpg',
#  '124.jpg',
#  '125.jpg',
#  '126.jpg',
#  '129.jpg',
#  '13.jpg',
#  '130.jpg',
#  '131.jpg',
#  '132.jpg',
#  '133.jpg',
#  '134.jpg',
#  '136.jpg',
# ...

# %%
for filename in os.listdir(source_folder):
    #if filename are in list
    if filename in list:
        #copy file from source to destination
        shutil.copy(os.path.join(source_folder, filename), destination_folder)
