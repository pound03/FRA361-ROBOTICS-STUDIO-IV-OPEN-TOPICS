# %%
#!/usr/bin/python3

import rclpy
from rclpy.node import Node
import sys
from cv_bridge import CvBridge
from sensor_msgs.msg import Image
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = cv.imread('/home/carver/kim_open_topic/linux/ws/src/fake_image/images/1.jpg')

# %%
#plot with rgb
plt.imshow(cv.cvtColor(image, cv.COLOR_BGR2RGB))
plt.show()

# %%
#add circle on center copy image to not change original
image2 = image.copy()
x = 55//2
y = 480//2
r = 10
cv.circle(image2, (x, y), r, (0, 0, 255), -1)
plt.imshow(cv.cvtColor(image2, cv.COLOR_BGR2RGB))
